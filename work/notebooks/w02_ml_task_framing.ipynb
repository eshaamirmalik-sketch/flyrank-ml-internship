# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eshaamirmalik-sketch/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# 1. My Lane as an ML Task (Type)

**Lane:** Refresh / Content Opportunity Scoring

**ML Task Type:** Scoring / Ranking

This project is a scoring and ranking task. The goal is to rank content pages based on their likelihood of benefiting from a content refresh. Instead of predicting a simple yes/no answer, the model assigns each page an opportunity score so content teams can prioritize which pages to review first.
"""))
# Out:
# # 1. My Lane as an ML Task (Type)
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# **ML Task Type:** Scoring / Ranking
#
# This project is a scoring and ranking task. The goal is to rank content pages based on their likelihood of benefiting from a content refresh. Instead of predicting a simple yes/no answer, the model assigns each page an opportunity score so content teams can prioritize which pages to review first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# 2. Target or Proxy

The dataset does not contain a direct label indicating whether a page should be refreshed. Therefore, I created a simple proxy target called **refresh_opportunity** for illustration. In this notebook, a page is marked as a refresh opportunity when it has a downward trend and a click-through rate below the dataset median. This is only a preliminary example to demonstrate the ML framing and is not the final target that will be used in the capstone project.
"""))
# Out:
# # 2. Target or Proxy
#
# The dataset does not contain a direct label indicating whether a page should be refreshed. Therefore, I created a simple proxy target called **refresh_opportunity** for illustration. In this notebook, a page is marked as a refresh opportunity when it has a downward trend and a click-through rate below the dataset median. This is only a preliminary example to demonstrate the ML framing and is not the final target that will be used in the capstone project.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# 3. Success Metric

The project will be successful if the ranking helps identify pages that deserve review before lower-priority pages. A useful model should provide practical decision support by placing high-opportunity pages near the top of the ranked list. The recommendations will be evaluated by their usefulness for content teams rather than perfect prediction accuracy.
"""))
# Out:
# # 3. Success Metric
#
# The project will be successful if the ranking helps identify pages that deserve review before lower-priority pages. A useful model should provide practical decision support by placing high-opportunity pages near the top of the ranked list. The recommendations will be evaluated by their usefulness for content teams rather than perfect prediction accuracy.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv(path)

print(df.shape)
df.head()
columns = [
    "content_id",
    "trend_direction",
    "impressions_90d",
    "ctr",
    "avg_position",
    "engagement_rate"
]

df[columns].head()
target_preview = df[[
    "content_id",
    "trend_direction",
    "impressions_90d",
    "ctr"
]].copy()

target_preview["refresh_opportunity"] = (
    (target_preview["trend_direction"] == "down") &
    (target_preview["ctr"] < target_preview["ctr"].median())
).astype(int)

target_preview.head(10)
# Out:
# (30000, 44)
#              content_id trend_direction  impressions_90d   ctr  \
# 0  content_304f48230142            down             3803  0.76
# 1  content_a1fb4e703a9e            down            15320  0.05
# 2  content_9aa793d4d895            down            12581  0.09
# 3  content_331d6c4de07b          stable            11751  0.49
# 4  content_d99b7a2d90ca            down            19140  0.13
# 5  content_d4084a4bc775            down             3970  0.03
# 6  content_9a34b442b552            down               20  0.00
# 7  content_a63219c6e95a          stable             1724  0.06
# 8  content_5e6c160719bc            down            32574  0.09
# 9  content_c27558df2b0c            down             1240  0.16
#
#    refresh_opportunity
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0
# 5                    1
# 6                    1
# 7                    0
# 8                    0
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
display(Markdown("""
# 5. Why ML Beats a Fixed Rule Here

A fixed rule, such as refreshing every page with a low click-through rate, considers only a single signal and ignores other important factors such as impressions, ranking position, engagement rate, content quality, and search trends. Machine learning can analyze multiple signals together and learn complex patterns that are difficult to represent with manually defined thresholds. This allows the system to provide more accurate decision support by identifying which pages are most likely to benefit from updates, while still allowing human reviewers to make the final decision.
"""))
# Out:
# # 5. Why ML Beats a Fixed Rule Here
#
# A fixed rule, such as refreshing every page with a low click-through rate, considers only a single signal and ignores other important factors such as impressions, ranking position, engagement rate, content quality, and search trends. Machine learning can analyze multiple signals together and learn complex patterns that are difficult to represent with manually defined thresholds. This allows the system to provide more accurate decision support by identifying which pages are most likely to benefit from updates, while still allowing human reviewers to make the final decision.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
